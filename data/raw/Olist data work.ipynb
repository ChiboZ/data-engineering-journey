# %%
import pandas as pd 
df_cust = pd.read_csv(r'data/raw/olist_customers_dataset.csv')
df_geo = pd.read_csv(r'F:\GitHub projects\data\raw\olist_geolocation_dataset.csv')
df_order_items = pd.read_csv(r'data\raw\olist_order_items_dataset.csv')
df_pmt = pd.read_csv(r'F:\GitHub projects\data\raw\olist_order_payments_dataset.csv')
df_reviews = pd.read_csv(r'F:\GitHub projects\data\raw\olist_order_reviews_dataset.csv')
df_orders = pd.read_csv(r'data\raw\olist_orders_dataset.csv')
df_products = pd.read_csv(r'data\raw\olist_products_dataset.csv')
df_sellers = pd.read_csv(r'data\raw\olist_sellers_dataset.csv')
df_category = pd.read_csv(r'data\raw\product_category_name_translation.csv')

# %%
df_cust.tail()
# Out:
#                             customer_id                customer_unique_id  \
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix    customer_city customer_state
# 99436                      3937        sao paulo             SP
# 99437                      6764  taboao da serra             SP
# 99438                     60115        fortaleza             CE
# 99439                     92120           canoas             RS
# 99440                      6703            cotia             SP

# %%
df_cust.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
df_cust.dtypes
# Out:
# customer_id                   str
# customer_unique_id            str
# customer_zip_code_prefix    int64
# customer_city                 str
# customer_state                str
# dtype: object

# %%
df_cust
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
df_cust['customer_zip_code_prefix'] = df_cust['customer_zip_code_prefix'].astype(str).str.zfill(5)

# %%
df_cust.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_zip_code_prefix          customer_city customer_state
# 0                    14409                 franca             SP
# 1                    09790  sao bernardo do campo             SP
# 2                    01151              sao paulo             SP
# 3                    08775        mogi das cruzes             SP
# 4                    13056               campinas             SP

# %%
df_cust['customer_city'].str.contains('[ãáàâéêíóôõúç]', regex=True).sum()
# Out:
# np.int64(0)

# %%
df_geo.tail()
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 1000158         tapejara                RS
# 1000159   getulio vargas                RS
# 1000160         tapejara                RS
# 1000161  david canabarro                RS
# 1000162         tapejara                RS

# %%
df_geo.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                   str
# geolocation_state                  str
# dtype: object

# %%
df_geo['geolocation_city'] = df_geo['geolocation_city'].str.replace('Ã' ,'a')

# %%
df_geo.loc[170460, 'geolocation_city']
# Out:
# 'taboão da serra'

# %%
df_geo.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
duplicates_geo = df_geo[df_geo.duplicated(keep=False)]

# %%
duplicates_geo
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 6                               1047       -23.546273       -46.641225
# 7                               1013       -23.546923       -46.634264
# ...                              ...              ...              ...
# 1000153                        99970       -28.343273       -51.873734
# 1000154                        99950       -28.070493       -52.011342
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
df_order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
df_order_items.dtypes
# Out:
# order_id                   str
# order_item_id            int64
# product_id                 str
# seller_id                  str
# shipping_limit_date        str
# price                  float64
# freight_value          float64
# dtype: object

# %%
df_order_items.shape
# Out:
# (112650, 7)

# %%
duplicates_order_items = df_order_items[df_order_items.duplicated(keep= False)]
duplicates_order_items
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value]
# Index: []

# %%
df_order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
print(df_order_items['shipping_limit_date'].iloc[0])
print(repr(df_order_items['shipping_limit_date'].iloc[0]))
# Out:
# 2017-09-19 09:45:35
# '2017-09-19 09:45:35'

# %%
df_order_items['shipping_limit_date'] = pd.to_datetime(df_order_items['shipping_limit_date'])

# %%
df_order_items.dtypes
# Out:
# order_id                          str
# order_item_id                   int64
# product_id                        str
# seller_id                         str
# shipping_limit_date    datetime64[us]
# price                         float64
# freight_value                 float64
# dtype: object

# %%
duplicates_order_items_2 = df_order_items['order_id'].duplicated(keep= False)
df_order_items[duplicates_order_items_2].sort_values('order_id').head(20)
# Out:
#                              order_id  order_item_id  \
# 13   0008288aa423d2a3f00fcb17cd7d8719              1
# 14   0008288aa423d2a3f00fcb17cd7d8719              2
# 32   00143d0f86d6fbd9f9b38ab440ac16f5              1
# 33   00143d0f86d6fbd9f9b38ab440ac16f5              2
# 34   00143d0f86d6fbd9f9b38ab440ac16f5              3
# 42   001ab0a7578dd66cd4b0a71f5b6e1e41              1
# 43   001ab0a7578dd66cd4b0a71f5b6e1e41              2
# 44   001ab0a7578dd66cd4b0a71f5b6e1e41              3
# 49   001d8f0e34a38c37f7dba2a37d4eba8b              2
# 48   001d8f0e34a38c37f7dba2a37d4eba8b              1
# 75   002c9def9c9b951b1bec6d50753c9891              1
# 76   002c9def9c9b951b1bec6d50753c9891              2
# 80   002f98c0f7efd42638ed6100ca699b42              1
# 81   002f98c0f7efd42638ed6100ca699b42              2
# 87   003324c70b19a16798817b2b3640e721              1
# 88   003324c70b19a16798817b2b3640e721              2
# 91   00337fe25a3780b3424d9ad7c5a4b35e              1
# ...

# %%
df_pmt.tail()
# Out:
#                                 order_id  payment_sequential payment_type  \
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# 103881                     1         363.31
# 103882                     2          96.80
# 103883                     1          47.77
# 103884                     5         369.54
# 103885                     1         191.58

# %%
df_pmt.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
df_pmt.dtypes
# Out:
# order_id                    str
# payment_sequential        int64
# payment_type                str
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
df_pmt.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
df_reviews.head(20)
# Out:
#                            review_id                          order_id  \
# 0   7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1   80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2   228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3   e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4   f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 5   15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6   07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# 7   7c6400515c67679fbee952a7525281ef  c31a859e34e3adac22f376954e19b39d
# 8   a3f6f7f6f433de0aefbb97da197c554c  9c214ac970e84273583ab523dfafd09b
# 9   8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 10  c9cfd2d5ab5911836ababae136c3a10c  cdf9aa68e72324eeb25c7de974696ee2
# 11  96052551d87e5f62e6c9f6974ec392e9  3d374c9e46530bb5ed4a7648915306a6
# ...

# %%
df_reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
df_reviews.iloc[0]
# Out:
# review_id                  7bc2406110b926393aa56f80a40eba40
# order_id                   73fc7af87114b39712e6da79b0a377eb
# review_score                                              4
# review_comment_title                                    NaN
# review_comment_message                                  NaN
# review_creation_date                    2018-01-18 00:00:00
# review_answer_timestamp                 2018-01-18 21:46:59
# Name: 0, dtype: object

# %%
df_reviews.fillna('no review placed' , inplace= True)
df_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
duplicates_reviews = df_reviews['review_id'].duplicated(keep= False)
duplicates_reviews
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99219    False
# 99220    False
# 99221    False
# 99222    False
# 99223    False
# Name: review_id, Length: 99224, dtype: bool

# %%
the_duplicates = df_reviews[df_reviews['review_id'].duplicated()== 1]

# %%
df_reviews = df_reviews.drop(the_duplicates.index)

# %%
df_reviews.reset_index(drop= True , inplace= True)

# %%
df_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 98405  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 98406  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 98407  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 98408  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 98409  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
df_sellers[df_sellers['seller_id'].duplicated()== 1]
# Out:
# Empty DataFrame
# Columns: [seller_id, seller_zip_code_prefix, seller_city, seller_state]
# Index: []

# %%
df_sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
df_sellers['seller_zip_code_prefix'] = df_sellers['seller_zip_code_prefix'].str.zfill(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df_sellers['seller_zip_code_prefix'] = df_sellers['seller_zip_code_prefix'].str.zfill(5)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# ...

# %%
df_sellers['seller_zip_code_prefix'] = df_sellers['seller_zip_code_prefix'].astype(str)

# %%
df_sellers
# Out:
#                              seller_id seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                  13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                  13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                  20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                  04195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                  12914
# ...                                ...                    ...
# 3090  98dddbc4601dd4443ca174359b237166                  87111
# 3091  f8201cab383e484733266d1906e2fdfa                  88137
# 3092  74871d19219c7d518d0090283e03c137                  04650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                  96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                  12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
df_products.tail()
# Out:
#                              product_id              product_category_name  \
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 32946                 45.0                        67.0                 2.0
# 32947                 41.0                       971.0                 1.0
# 32948                 50.0                       799.0                 1.0
# 32949                 60.0                       156.0                 2.0
# 32950                 58.0                       309.0                 1.0
#
# ...

# %%
df_products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
df_products[df_products['product_id'].duplicated()==1]
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []

# %%
df_products.iloc[90]
# Out:
# product_id                    f9ecf420c38b90a8af8e7f70fd789264
# product_category_name                            esporte_lazer
# product_name_lenght                                       43.0
# product_description_lenght                               101.0
# product_photos_qty                                         1.0
# product_weight_g                                         600.0
# product_length_cm                                         50.0
# product_height_cm                                         10.0
# product_width_cm                                          12.0
# Name: 90, dtype: object

# %%
df_products['product_category_name'] = df_products['product_category_name'].str.replace("_" , " " , regex= False)

# %%
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao ferramentas iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama mesa banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica acessorios
# 32950  106392145fca363410d287a815be6de4                    cama mesa banho
#
# ...

# %%
merged = df_orders.merge(df_cust, on='customer_id', how='left')
print(len(merged))
# Out:
# 99441

# %%
merged = merged.merge(df_order_items, on='order_id', how='left')
print(len(merged))
# Out:
# 113425

# %%
merged = merged.merge(df_pmt, on='order_id', how='left')
print(len(merged))
# Out:
# 118434

# %%
merged = merged.merge(df_reviews, on='order_id', how='left')
print(len(merged))
# Out:
# 118763

# %%
merged = merged.merge(df_products, on='product_id', how='left')
print(len(merged))
# Out:
# 118763

# %%
merged = merged.merge(df_sellers, on='seller_id', how='left')
print(len(merged))
# Out:
# 118763

# %%
merged.to_csv('data/proccessed/olist_merged.csv', index=False)

# %%
Final_merge = pd.read_csv(r"F:\GitHub projects\data\proccessed\olist_merged.csv")

# %%
Final_merge
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 118758  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 118759  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 118760  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118761  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118762  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...
